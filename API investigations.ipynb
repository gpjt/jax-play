# %%
import jax

# %%
jax.sigmoid
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 jax.sigmoid
#
# File ~/Dev/jax-play/.venv/lib/python3.14/site-packages/jax/_src/deprecations.py:57, in deprecation_getattr.<locals>.getattr(name)
#      55   warnings.warn(message, DeprecationWarning, stacklevel=2)
#      56   return fn
# ---> 57 raise AttributeError(f"module {module!r} has no attribute {name!r}")
#
# AttributeError: module 'jax' has no attribute 'sigmoid'

# %%
jax.nn.sigmoid
# Out:
# <PjitFunction of <function sigmoid at 0x7f6ea33a3e20>>
